# %% [markdown]
# # Proyect_data Functions

# %%
import pandas as pd
proyect_data = pd.read_csv('/Users/juandediegosuanzes/desktop/ih_datamadpt0420_project_m1/data/raw/proyect_data.csv')
proyect_data = proyect_data.drop(columns=['Unnamed: 0'])
proyect_data
# Out:
#                                       uuid dem_education_level  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82                  no
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82                high
# 2     83127080-da3d-0133-c74f-0a81e8b09a82                 NaN
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82                high
# 4     24954a70-db98-0133-4a64-0a81e8b09a82                high
# ...                                    ...                 ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82                high
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82                high
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82                 low
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82                 low
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82                high
#
#      dem_full_time_job               normalized_job_code  \
# 0                   no                               NaN
# 1                  yes  861a9b9151e11362eb3c77ca914172d0
# ...

# %%
proyect_data['gender'].value_counts()
# Out:
# male      3796
# female    2581
# Male      1298
# FeMale    1125
# Fem        849
# Name: gender, dtype: int64

# %%
#gender cleaning from 4 to 2 (female, male)
def clean_gender(x):
    x_lower = x.lower()
    if x_lower == 'fem':
        xf = x_lower.replace('fem','female')
        return xf
    else:
        return x_lower
proyect_data['gender'] = proyect_data['gender'].apply(clean_gender)

#first word to capital letter
def to_capitalize(x):
    return x.capitalize()
proyect_data['gender'] = proyect_data['gender'].apply(to_capitalize)
proyect_data

#comprobation
#proyect_data['gender'].value_counts()
# Out:
#                                       uuid dem_education_level  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82                  no
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82                high
# 2     83127080-da3d-0133-c74f-0a81e8b09a82                 NaN
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82                high
# 4     24954a70-db98-0133-4a64-0a81e8b09a82                high
# ...                                    ...                 ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82                high
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82                high
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82                 low
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82                 low
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82                high
#
#      dem_full_time_job               normalized_job_code  \
# 0                   no                               NaN
# 1                  yes  861a9b9151e11362eb3c77ca914172d0
# ...

# %%
proyect_data['rural'].value_counts()
# Out:
# urban          3842
# city           1664
# rural          1517
# Non-Rural      1372
# Country         772
# countryside     482
# Name: rural, dtype: int64

# %%
#function to clean rural columns, to just 'urban' and 'rural'
def rural_column(x):
    proyect_data['rural'] = proyect_data['rural'].str.lower()
    proyect_data['rural'] = proyect_data['rural'].str.replace('city', 'urban').replace('non-rural', 'urban').replace('countryside', 'rural').replace('country', 'rural')
    return x.rural_column()
proyect_data['rural'] = proyect_data['rural'].apply(rural_column)
proyect_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f7dc8ec8b41a> in <module>
#       4     proyect_data['rural'] = proyect_data['rural'].replace('city', 'urban').replace('non-rural', 'urban').replace('countryside', 'rural').replace('country', 'rural')
#       5     return x.rural_column()
# ----> 6 proyect_data['rural'] = proyect_data['rural'].apply(rural_column)
#       7 proyect_data
#
# /opt/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
proyect_data['rural'].value_counts()
#proyect_data
# Out:
# urban    6878
# rural    2771
# Name: rural, dtype: int64

# %%
def proyect_data(path):
    print('collecting database...')
    sqlitepath = path
    engine = create_engine(f'sqlite:///{sqlitepath}')
    tables = pd.read_sql_query("""SELECT name FROM sqlite_master WHERE type = 'table'""", engine)
    tables_list = tables['name'].to_list()
    x = [pd.read_sql_query(f'SELECT * FROM {i}', engine) for i in tables_list]
    df_data = reduce(lambda left, right: pd.merge(left, right, on='uuid'), x)

    return proyect_data

proyect_data()

# %%
for i in grouped['Country']:
    filter = input('Que pais quieres analizar: ')
    if filter in list(grouped['Country']):
        country = grouped[grouped['Country']== filter].groupby(['Country', 'Job_title', 'Rural', 'Percentage']).agg({Quantity: 'sum'})
        print(country)
        break
    else:
        country = grouped.groupby(['Country', 'Job_title', 'Rural', 'Percentage']).agg({Quantity: 'sum'})
        print(country)
        break
