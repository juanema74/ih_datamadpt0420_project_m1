# %% [markdown]
# ### TABLES

# %%
import pandas as pd
from sqlalchemy import create_engine
sqlitepath = '/Users/juandediegosuanzes/Desktop/ih_datamadpt0420_project_m1/data/raw/raw_data_project_m1.db'
engine = create_engine(f'sqlite:///{sqlitepath}')

# %%
# list all tables in database
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", engine)
# Out:
#             name
# 0  personal_info
# 1   country_info
# 2    career_info
# 3      poll_info

# %%
#personal_info table
df_sqlite = pd.read_sql_query("select * from personal_info", engine)

df_sqlite
#df_sqlite.head()
# Out:
#                                       uuid           age  gender  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82  61 years old    male
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82  57 years old    male
# 2     83127080-da3d-0133-c74f-0a81e8b09a82  32 years old    male
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82  45 years old    Male
# 4     24954a70-db98-0133-4a64-0a81e8b09a82  41 years old     Fem
# ...                                    ...           ...     ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82  37 years old  FeMale
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82  53 years old    Male
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82          1992    male
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82  47 years old    male
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82  51 years old  FeMale
#
#      dem_has_children age_group
# 0                  NO     40_65
# 1                 yES     40_65
# 2                  nO     26_39
# 3                 YES     40_65
# ...

# %%
#country_info table
df_sqlite = pd.read_sql_query("select * from country_info", engine)

df_sqlite
#df_sqlite.head()
# Out:
#                                       uuid country_code        rural
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82           AT  countryside
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82           AT        urban
# 2     83127080-da3d-0133-c74f-0a81e8b09a82           AT         city
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82           AT      Country
# 4     24954a70-db98-0133-4a64-0a81e8b09a82           AT         city
# ...                                    ...          ...          ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82           SK        urban
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82           SK        urban
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82           SK    Non-Rural
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82           SK         city
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82           SK         city
#
# [9649 rows x 3 columns]

# %%
#career_info table
df_sqlite = pd.read_sql_query("select * from career_info", engine)

df_sqlite
#df_sqlite.head()
# Out:
#                                       uuid dem_education_level  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82                  no
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82                high
# 2     83127080-da3d-0133-c74f-0a81e8b09a82                None
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82                high
# 4     24954a70-db98-0133-4a64-0a81e8b09a82                high
# ...                                    ...                 ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82                high
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82                high
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82                 low
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82                 low
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82                high
#
#      dem_full_time_job               normalized_job_code
# 0                   no                              None
# 1                  yes  861a9b9151e11362eb3c77ca914172d0
# ...

# %%
#poll_info table
df_sqlite = pd.read_sql_query("select * from poll_info", engine)

df_sqlite
#df_sqlite.head()
# Out:
#                                       uuid  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82
# 2     83127080-da3d-0133-c74f-0a81e8b09a82
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82
# 4     24954a70-db98-0133-4a64-0a81e8b09a82
# ...                                    ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82
#
#      question_bbi_2016wave4_basicincome_awareness  \
# 0                       I know something about it
# 1                           I understand it fully
# 2             I have heard just a little about it
# 3             I have heard just a little about it
# 4             I have heard just a little about it
# ...                                           ...
# 9644                        I understand it fully
# ...

# %%
#data frame with the 4 tables togehter
proyect_data = pd.read_sql_query("""SELECT * FROM career_info cif  
inner join poll_info pif on cif.uuid = pif.uuid  
inner join country_info ci on ci.uuid = pif.uuid 
inner join personal_info pi on pi.uuid = ci.uuid""",engine)
proyect_data
# Out:
#                                       uuid dem_education_level  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82                  no
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82                high
# 2     83127080-da3d-0133-c74f-0a81e8b09a82                None
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82                high
# 4     24954a70-db98-0133-4a64-0a81e8b09a82                high
# ...                                    ...                 ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82                high
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82                high
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82                 low
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82                 low
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82                high
#
#      dem_full_time_job               normalized_job_code  \
# 0                   no                              None
# 1                  yes  861a9b9151e11362eb3c77ca914172d0
# ...

# %%
proyect_data.to_csv('/Users/juandediegosuanzes/desktop/ih_datamadpt0420_project_m1/data/raw/proyect_data.csv')

# %% [markdown]
# # API

# %%
import requests

# %%
jobs_api = []
job_codes = set(proyect_data['normalized_job_code'])

for i in job_codes:
    response = requests.get(f'http://api.dataatwork.org/v1/jobs/{i}')
    jobs_json = response.json()
    jobs_api.append(jobs_json)

# %%
df_jobs_api = pd.DataFrame(jobs_api)
df_jobs_api = pd.DataFrame((jobs_api), columns=['uuid','title', 'normalized_job_title'])
df_jobs_api = df_jobs_api.rename(columns={'uuid': 'normalize_job_tilte'})
df_jobs_api
# Out:
#                   normalize_job_tilte  \
# 0    ced804d972b03cca6d523ec8925a7943
# 1    569da68cdcac43a3b4a0126ea9170570
# 2    132aa9e82c5d4c8a395342d0a6e22c5c
# 3    b24ece3300d2f8ab34f9553e531183d6
# 4    04c27c76b463a917800549cf88a59961
# ..                                ...
# 152  776bf47111206d31ccf835650e1054cc
# 153  bdf4dcd92089bc17345de83f4d06090f
# 154  e2f68bf748aea2c7d2254550c0c92b23
# 155  fcaf4aac737e53ad24b9f32f08b8740f
# 156  0044971fda4a261b6049a63817913e95
#
#                                                  title  \
# 0           Oracle Database Administrator (Oracle DBA)
# 1                                    Database Designer
# 2    Electronic Data Interchange System Developer (...
# 3              Data Processing Systems Project Planner
# 4                       Data Communications Technician
# ..                                                 ...
# 152                                        Data Typist
# ...

# %% [markdown]
# ### WEB SCRAPING

# %%
import requests
from bs4 import BeautifulSoup
import lxml.html as lh
import pandas as pd

url = 'https://ec.europa.eu/eurostat/statistics-explained/index.php/Glossary:Country_codes'
html = requests.get(url).content

soup = BeautifulSoup(html, 'lxml')
table = soup.find('table')

df_table = pd.DataFrame(table)

# %%
import re
dirty_list = []
rows = table.find_all('tr')
for tr in rows:
    element_row = tr.find_all('td')
    for td in element_row:
        dirty_list.append(td.text)
#print(dirty_list)

clean_list = []
for i in dirty_list:
    f = i.replace('\n', '').replace('(','').replace(')','')
    clean_list.append(f)
#print(clean_list)

row_split = 2
rows_refactored = [clean_list[x:x+row_split] for x in range(0, len(clean_list), row_split)]
df_countries =pd.DataFrame(rows_refactored,columns = {'country_name','country_code'})
df_countries
# Out:
#    country_name country_code
# 0       Belgium           BE
# 1        Greece           EL
# 2     Lithuania           LT
# 3      Portugal           PT
# 4      Bulgaria           BG
# 5         Spain           ES
# 6    Luxembourg           LU
# 7       Romania           RO
# 8       Czechia           CZ
# 9        France           FR
# 10      Hungary           HU
# 11     Slovenia           SI
# 12      Denmark           DK
# 13      Croatia           HR
# 14        Malta           MT
# 15     Slovakia           SK
# 16      Germany           DE
# 17        Italy           IT
# 18  Netherlands           NL
# 19      Finland           FI
# 20      Estonia           EE
# 21       Cyprus           CY
# 22      Austria           AT
# 23       Sweden           SE
# 24      Ireland           IE
# 25       Latvia           LV
# 26       Poland           PL
